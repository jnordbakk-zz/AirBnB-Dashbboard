# %%
import os
import pandas as pd

# %%
listings_file = os.path.join('../static/Data','listings.csv')

# %%
raw_listings_df = pd.read_csv(listings_file, encoding="ISO-8859-1")

# %%
print(raw_listings_df.head())
# Out:
#      id                        listing_url     scrape_id last_scraped  \
# 0   958   https://www.airbnb.com/rooms/958  2.018080e+13       8/6/18
# 1  5858  https://www.airbnb.com/rooms/5858  2.018080e+13       8/6/18
# 2  7918  https://www.airbnb.com/rooms/7918  2.018080e+13       8/6/18
# 3  8142  https://www.airbnb.com/rooms/8142  2.018080e+13       8/6/18
# 4  8339  https://www.airbnb.com/rooms/8339  2.018080e+13       8/6/18
#
#                                                 name  \
# 0                Bright, Modern Garden Unit - 1BR/1B
# 1                                 Creative Sanctuary
# 2         A Friendly Room - UCSF/USF - San Francisco
# 3  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                    Historic Alamo Square Victorian
#
#                                              summary  \
# 0  Our bright garden unit overlooks a grassy back...
# 1                                                NaN
# 2  Nice and good public transportation.  7 minute...
# 3  Nice and good public transportation.  7 minute...
# 4  Pls email before booking.  Interior featured i...
#
#                                                space  \
# 0  Newly remodeled, modern, and bright garden uni...
# 1  We live in a large Victorian house on a quiet ...
# 2  Room rental-sunny view room/sink/Wi Fi (inner ...
# 3  Room rental Sunny view Rm/Wi-Fi/TV/sink/large ...
# 4  Please send us a quick message before booking ...
#
#                                          description experiences_offered  \
# 0  Our bright garden unit overlooks a grassy back...                none
# 1  We live in a large Victorian house on a quiet ...                none
# 2  Nice and good public transportation.  7 minute...                none
# 3  Nice and good public transportation.  7 minute...                none
# 4  Pls email before booking.  Interior featured i...                none
#
#                                neighborhood_overview        ...          \
# 0  *Quiet cul de sac in friendly neighborhood *St...        ...
# 1  I love how our neighborhood feels quiet but is...        ...
# 2  Shopping old town, restaurants, McDonald, Whol...        ...
# 3                                                NaN        ...
# 4                                                NaN        ...
#
#   requires_license      license jurisdiction_names instant_bookable  \
# 0                t  STR-0001256  {"SAN FRANCISCO"}                f
# 1                t          NaN  {"SAN FRANCISCO"}                f
# 2                t          NaN  {"SAN FRANCISCO"}                f
# 3                t          NaN  {"SAN FRANCISCO"}                f
# 4                t  STR-0000264  {"SAN FRANCISCO"}                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     moderate
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
#
#    require_guest_profile_picture require_guest_phone_verification  \
# 0                              f                                f
# 1                              f                                f
# 2                              f                                f
# 3                              f                                f
# 4                              t                                t
#
#    calculated_host_listings_count  reviews_per_month
# 0                               1               1.38
# 1                               1               0.99
# 2                               9               0.16
# 3                               9               0.15
# 4                               2               0.24
#
# [5 rows x 96 columns]

# %%
listings_df = raw_listings_df[['id','listing_url','name','picture_url','host_name','host_response_rate','host_is_superhost',
                              'host_has_profile_pic','host_thumbnail_url','host_picture_url','neighbourhood','property_type',
                              'bedrooms','bathrooms','price','weekly_price','monthly_price','availability_365','longitude',
                              'latitude','number_of_reviews','review_scores_rating','reviews_per_month']]
listings_df.head()
# Out:
#      id                        listing_url  \
# 0   958   https://www.airbnb.com/rooms/958
# 1  5858  https://www.airbnb.com/rooms/5858
# 2  7918  https://www.airbnb.com/rooms/7918
# 3  8142  https://www.airbnb.com/rooms/8142
# 4  8339  https://www.airbnb.com/rooms/8339
#
#                                                 name  \
# 0                Bright, Modern Garden Unit - 1BR/1B
# 1                                 Creative Sanctuary
# 2         A Friendly Room - UCSF/USF - San Francisco
# 3  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                    Historic Alamo Square Victorian
#
#                                          picture_url         host_name  \
# 0  https://a0.muscache.com/im/pictures/51332160/0...             Holly
# 1  https://a0.muscache.com/im/pictures/17714/3a7a...  Philip And Tania
# 2  https://a0.muscache.com/im/pictures/26356/8030...             Aaron
# 3  https://a0.muscache.com/im/pictures/27832/3b1f...             Aaron
# 4  https://a0.muscache.com/im/pictures/6f84a7c2-e...              Rosy
#
#   host_response_rate host_is_superhost host_has_profile_pic  \
# 0                92%                 t                    t
# 1               100%                 f                    t
# 2               100%                 f                    t
# 3               100%                 f                    t
# 4               100%                 f                    t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/efdad96a-3...
# 1  https://a0.muscache.com/im/users/8904/profile_...
# 2  https://a0.muscache.com/im/users/21994/profile...
# 3  https://a0.muscache.com/im/users/21994/profile...
# 4  https://a0.muscache.com/im/users/24215/profile...
#
#                                     host_picture_url        ...          \
# 0  https://a0.muscache.com/im/pictures/efdad96a-3...        ...
# 1  https://a0.muscache.com/im/users/8904/profile_...        ...
# 2  https://a0.muscache.com/im/users/21994/profile...        ...
# 3  https://a0.muscache.com/im/users/21994/profile...        ...
# 4  https://a0.muscache.com/im/users/24215/profile...        ...
#
#   bathrooms     price  weekly_price  monthly_price availability_365  \
# 0       1.0  $170.00     $1,120.00      $4,200.00               122
# 1       1.0  $235.00     $1,600.00      $5,500.00               365
# 2       4.0   $65.00       $485.00      $1,685.00               365
# 3       4.0   $65.00       $490.00      $1,685.00               328
# 4       1.5  $675.00            NaN            NaN               78
#
#     longitude   latitude  number_of_reviews  review_scores_rating  \
# 0 -122.433856  37.769310                152                  97.0
# 1 -122.421018  37.745112                112                  98.0
# 2 -122.452505  37.766690                 17                  85.0
# 3 -122.451828  37.764872                  7                  91.0
# 4 -122.436374  37.775249                 26                  97.0
#
#    reviews_per_month
# 0               1.38
# 1               0.99
# 2               0.16
# 3               0.15
# 4               0.24
#
# [5 rows x 23 columns]

# %%
#listings_df.columns=listings_df.columns.str.replace('id','ids') # changes name of column
#listings_df=listings_df.replace('\$\,','',regex=True)

# %%
#listings_df['price'].replace(regex=True,inplace=True,to_replace=r'/$',value=r'')

# %%
listings_df.head()
# Out:
#      id                        listing_url  \
# 0   958   https://www.airbnb.com/rooms/958
# 1  5858  https://www.airbnb.com/rooms/5858
# 2  7918  https://www.airbnb.com/rooms/7918
# 3  8142  https://www.airbnb.com/rooms/8142
# 4  8339  https://www.airbnb.com/rooms/8339
#
#                                                 name  \
# 0                Bright, Modern Garden Unit - 1BR/1B
# 1                                 Creative Sanctuary
# 2         A Friendly Room - UCSF/USF - San Francisco
# 3  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                    Historic Alamo Square Victorian
#
#                                          picture_url         host_name  \
# 0  https://a0.muscache.com/im/pictures/51332160/0...             Holly
# 1  https://a0.muscache.com/im/pictures/17714/3a7a...  Philip And Tania
# 2  https://a0.muscache.com/im/pictures/26356/8030...             Aaron
# 3  https://a0.muscache.com/im/pictures/27832/3b1f...             Aaron
# 4  https://a0.muscache.com/im/pictures/6f84a7c2-e...              Rosy
#
#   host_response_rate host_is_superhost host_has_profile_pic  \
# 0                92%                 t                    t
# 1               100%                 f                    t
# 2               100%                 f                    t
# 3               100%                 f                    t
# 4               100%                 f                    t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/efdad96a-3...
# 1  https://a0.muscache.com/im/users/8904/profile_...
# 2  https://a0.muscache.com/im/users/21994/profile...
# 3  https://a0.muscache.com/im/users/21994/profile...
# 4  https://a0.muscache.com/im/users/24215/profile...
#
#                                     host_picture_url        ...          \
# 0  https://a0.muscache.com/im/pictures/efdad96a-3...        ...
# 1  https://a0.muscache.com/im/users/8904/profile_...        ...
# 2  https://a0.muscache.com/im/users/21994/profile...        ...
# 3  https://a0.muscache.com/im/users/21994/profile...        ...
# 4  https://a0.muscache.com/im/users/24215/profile...        ...
#
#   bathrooms     price  weekly_price  monthly_price availability_365  \
# 0       1.0  $170.00     $1,120.00      $4,200.00               122
# 1       1.0  $235.00     $1,600.00      $5,500.00               365
# 2       4.0   $65.00       $485.00      $1,685.00               365
# 3       4.0   $65.00       $490.00      $1,685.00               328
# 4       1.5  $675.00            NaN            NaN               78
#
#     longitude   latitude  number_of_reviews  review_scores_rating  \
# 0 -122.433856  37.769310                152                  97.0
# 1 -122.421018  37.745112                112                  98.0
# 2 -122.452505  37.766690                 17                  85.0
# 3 -122.451828  37.764872                  7                  91.0
# 4 -122.436374  37.775249                 26                  97.0
#
#    reviews_per_month
# 0               1.38
# 1               0.99
# 2               0.16
# 3               0.15
# 4               0.24
#
# [5 rows x 23 columns]

# %%
price_df = listings_df[["neighbourhood","price"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('neighbourhood', 'price')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-0c0660c9a0da> in <module>()
# ----> 1 price_df = listings_df["neighbourhood","price"]
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('neighbourhood', 'price')

# %%
output_listings_file = os.path.join('../Data/','filtered_listings.csv')
listings_df.to_csv(output_listings_file, encoding='utf-8', index=False)
